# %% [markdown]
# # 05 Homework

# %% [markdown]
# ## Deployment

# %% [markdown]
# Q1. pipenv, version 2022.10.4

# %% [markdown]
# Q2. 08ef968f6b72033c16c479c966bf37ccd49b06ea91b765e1cc27afefe723920b
